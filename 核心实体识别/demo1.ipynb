# %% [markdown]
# 基于迁移学习和双向LSTM的核心实体识别
# 1：训练预料和测试预料都分词，目前用的是结巴分词
# 2：转化为5tag标注问题，构建训练标签
# 3：训练预料和测试预料一起训练word2vec模型
# 4：用双层双向LSTM训练标注模型，基于seq2seq的思想
# 5：用模型进行预测，预测准确率大约会在0.46~0.52波动
# 6：将预测结果当做标数据，与训练数据一起，重新训练模型
# 7：用新模型预测，预测准确率0.5-0.55
# 8：比较两次预测结果，取交集当做标签数据，与训练数据一起，重新训练模型
# 9：用新模型预测额，预测准确率基本保持在0.53-0.56
#
#
#
#
# 迁移学习体现在：
# 1：用训练语料和测试语料一起训练word2vec，使得词向量本捕捉了测试语料的语义
# 2：用训练预料训练模型
# 3：得到模型后，对测试语料预测，把预测结果跟训练预料一起训练新的模型
# 4：用心的模型预测，模型效果会有一定提升
# 5：对比两次预测结果，如果两次预测结果都一样，那说明这个预测结果很有可能是对的，用这“很有可能是对的”的测试结果来训练模型
# 6：用更新的模型预测
# 7：如果你愿意，可以接续重复第4 5 6 步。
#
# 双向LSTM的思路：
# 1：分词
# 2：转换为5tag标注问题（0:非核心实体，1:单词的核心实体，2:多词核心实体的首词，3:多词核心实体的中间部分，4:多词核心实体的末词）；
# 3：通过双向LSTM，直接对输入句子输出预测标注序列
# 4：通过 viterbi算法来获得标注结果
# 5：因为常规的LSTM存在后面的词比前面的词更重要的弊端，因此用双向LSTM

# %%
'''
基于迁移学习和双向LSTM的核心实体识别

迁移学习体现在：
1、用训练语料和测试语料一起训练Word2Vec，使得词向量本捕捉了测试语料的语义；
2、用训练语料训练模型；
3、得到模型后，对测试语料预测，把预测结果跟训练语料一起训练新的模型；
4、用新的模型预测，模型效果会有一定提升；
5、对比两次预测结果，如果两次预测结果都一样，那说明这个预测结果很有可能是对的，用这部分“很有可能是对的”的测试结果来训练模型；
6、用更新的模型预测；
7、如果你愿意，可以继续重复第4、5、6步。

双向LSTM的思路：
1、分词；
2、转换为5tag标注问题（0:非核心实体，1:单词的核心实体，2:多词核心实体的首词，3:多词核心实体的中间部分，4:多词核心实体的末词）；
3、通过双向LSTM，直接对输入句子输出预测标注序列；
4、通过viterbi算法来获得标注结果；
5、因为常规的LSTM存在后面的词比前面的词更重要的弊端，因此用双向LSTM。
'''
import numpy as np
import pandas as pd
import jieba
from tqdm import tqdm
import re

d = pd.read_json('data.json') #训练数据已经被预处理成标注json格式
d.index = range(len(d)) #重新定义一下索引，当然这只是有效显示效果
word_size = 128 #词向量维度
maxlen = 80 #句子截断长度


'''

修改分词函数，主要是：
1：英文和数字部分不分词，直接返回
2：双书名号的内容不分词
3：双引号里面如果是十字以内的内容不分词
4：超出范围内的字符全部替换为空格
5：分词使用结巴粉笔，并关闭新词发现功能
'''

not_cuts = re.compile(u'([\da-zA-Z \.]+)|《(.*?)》|“(.{1,10})”')
re_replace = re.compile(u'[^\u4e00-\u9fa50-9a-zA-Z《》\(\)（）“”·\.]')
def mycut(s):
    result = []
    j = 0
    s = re_replace.sub(' ', s)
    for i in not_cuts.finditer(s):
        result.extend(jieba.lcut(s[j:i.start()], HMM=False))
        if s[i.start()] in [u'《', u'“']:
            result.extend([s[i.start()], s[i.start()+1:i.end()-1], s[i.end()-1]])
        else:
            result.append(s[i.start():i.end()])
        j = i.end()
    result.extend(jieba.lcut(s[j:], HMM=False))
    return result


d['words'] = d['content'].apply(mycut) #分词

def label(k): #将输出结果转换为标签序列
    s = d['words'][k]
    r = ['0']*len(s)
    for i in range(len(s)):
        for j in d['core_entity'][k]:
            if s[i] in j:
                r[i] = '1'
                break
    s = ''.join(r)
    r = [0]*len(s)
    for i in re.finditer('1+', s):
        if i.end() - i.start() > 1:
            r[i.start()] = 2
            r[i.end()-1] = 4
            for j in range(i.start()+1, i.end()-1):
                r[j] = 3
        else:
            r[i.start()] = 1
    return r


d['label'] = map(label,tqdm(iter(d.index))) #输出tags

#随机打乱数据
idx = np.arange(len(d))
d.index = idx
np.random.shuffle(idx)
d = d.loc[idx]
d.index = range(len(d))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache H:\TEMP\jieba.cache
# Loading model cost 1.118 seconds.
# Prefix dict has been built succesfully.
# 0it [00:00, ?it/s]

# %%
d.head()
# Out:
#                                              content core_entity  \
# 0                              《秋思》是唐代诗人张籍创作的一首七言绝句。        [秋思]
# 1  张旭，中华书法家协会会员，甘肃岐黄书画院院士，中国石油书法家协会理事，甘肃书画家协会理事，陕...        [张旭]
# 2       吴江，字从岷，号与斋，弘治中筮仕刑部主事，迁员外郎……正德初，擢江西按察佥事，改佥河南。        [吴江]
# 3  我对西门町无感，因为我觉得吧，每一座城市都有个西门町，没有太多特色，我们在 台北 住的旅店就...       [西门町]
# 4  双月湾的海滩比簨寮湾更好看噢！更有大自然的原生态气质！ 很长的海滩，我们去的时候刚好下暴雨，...       [双月湾]
#
#                                                words  \
# 0    [《, 秋思, 》, 是, 唐代, 诗人, 张, 籍, 创作, 的, 一首, 七言绝句,  ]
# 1  [张旭,  , 中华, 书法家, 协会会员,  , 甘肃, 岐黄, 书画院, 院士,  , ...
# 2  [吴江,  , 字, 从, 岷,  , 号, 与, 斋,  , 弘治, 中, 筮, 仕, 刑...
# 3  [我, 对, 西门町, 无感,  , 因为, 我, 觉得, 吧,  , 每, 一座, 城市,...
# 4  [双, 月, 湾, 的, 海滩, 比, 簨, 寮, 湾, 更好, 看, 噢,  , 更, 有...
#
#                                 label
# 0  <map object at 0x0000021071014978>
# 1  <map object at 0x0000021071014978>
# 2  <map object at 0x0000021071014978>
# 3  <map object at 0x0000021071014978>
# 4  <map object at 0x0000021071014978>

# %%
#读入测试数据并进行分词
dd = open('opendata_20w',encoding='utf-8').read().split('\n')
dd = pd.DataFrame([dd]).T
dd.columns = ['content']
dd = dd[:-1]
print(u'测试语料分词中......')
dd['words'] = dd['content'].apply(mycut)
# Out:
# 测试语料分词中......

# %%
'''
用gensim来训练word2vec
1：联合训练语料和测试预料一起训练
2：经过测试用skip_gram效果会好些
'''

import gensim,logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)


word2vec = gensim.models.Word2Vec(dd['words'].append(d['words']),
                                  min_count=1,
                                  size=word_size,
                                  workers=20,
                                  iter=20,
                                  window=8,
                                  negative=8,
                                  sg=1
                                 )

word2vec.save('word2vec_words_final.model')
word2vec.init_sims(replace=True) #预先归一化，使得词向量不受尺度影响
print('正在进行第一次训练...')
# Out:
# C:\Users\Johnson\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# 2018-05-10 22:40:57,905 : INFO : collecting all words and their counts
# 2018-05-10 22:40:57,913 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-05-10 22:40:58,029 : INFO : PROGRESS: at sentence #10000, processed 265440 words, keeping 36463 word types
# 2018-05-10 22:40:58,186 : INFO : PROGRESS: at sentence #20000, processed 535609 words, keeping 57577 word types
# 2018-05-10 22:40:58,292 : INFO : PROGRESS: at sentence #30000, processed 800993 words, keeping 73190 word types
# 2018-05-10 22:40:58,608 : INFO : PROGRESS: at sentence #40000, processed 1435021 words, keeping 94129 word types
# 2018-05-10 22:40:59,008 : INFO : PROGRESS: at sentence #50000, processed 2169109 words, keeping 104638 word types
# 2018-05-10 22:40:59,318 : INFO : PROGRESS: at sentence #60000, processed 2891056 words, keeping 111642 word types
# 2018-05-10 22:40:59,569 : INFO : PROGRESS: at sentence #70000, processed 3620728 words, keeping 118366 word types
# 2018-05-10 22:40:59,808 : INFO : PROGRESS: at sentence #80000, processed 4353990 words, keeping 123387 word types
# 2018-05-10 22:41:00,084 : INFO : PROGRESS: at sentence #90000, processed 5098320 words, keeping 128354 word types
# 2018-05-10 22:41:00,395 : INFO : PROGRESS: at sentence #100000, processed 5815201 words, keeping 132800 word types
# 2018-05-10 22:41:00,618 : INFO : PROGRESS: at sentence #110000, processed 6569312 words, keeping 136887 word types
# 2018-05-10 22:41:00,820 : INFO : PROGRESS: at sentence #120000, processed 7270939 words, keeping 140565 word types
# 2018-05-10 22:41:01,023 : INFO : PROGRESS: at sentence #130000, processed 7990342 words, keeping 143886 word types
# 2018-05-10 22:41:01,332 : INFO : PROGRESS: at sentence #140000, processed 8695816 words, keeping 147348 word types
# 2018-05-10 22:41:01,533 : INFO : PROGRESS: at sentence #150000, processed 9492554 words, keeping 152226 word types
# 2018-05-10 22:41:01,721 : INFO : PROGRESS: at sentence #160000, processed 10254532 words, keeping 156049 word types
# 2018-05-10 22:41:01,902 : INFO : PROGRESS: at sentence #170000, processed 11024664 words, keeping 159832 word types
# 2018-05-10 22:41:02,088 : INFO : PROGRESS: at sentence #180000, processed 11720882 words, keeping 162325 word types
# 2018-05-10 22:41:02,283 : INFO : PROGRESS: at sentence #190000, processed 12457855 words, keeping 164845 word types
# 2018-05-10 22:41:02,449 : INFO : PROGRESS: at sentence #200000, processed 13141618 words, keeping 167298 word types
# 2018-05-10 22:41:02,542 : INFO : PROGRESS: at sentence #210000, processed 13453988 words, keeping 168765 word types
# 2018-05-10 22:41:02,571 : INFO : collected 169084 word types from a corpus of 13525385 raw words and 212236 sentences
# 2018-05-10 22:41:02,573 : INFO : Loading a fresh vocabulary
# 2018-05-10 22:41:03,699 : INFO : min_count=1 retains 169084 unique words (100% of original 169084, drops 0)
# 2018-05-10 22:41:03,701 : INFO : min_count=1 leaves 13525385 word corpus (100% of original 13525385, drops 0)
# 2018-05-10 22:41:04,288 : INFO : deleting the raw counts dictionary of 169084 items
# 2018-05-10 22:41:04,302 : INFO : sample=0.001 downsamples 26 most-common words
# 2018-05-10 22:41:04,307 : INFO : downsampling leaves estimated 10527021 word corpus (77.8% of prior 13525385)
# 2018-05-10 22:41:04,310 : INFO : estimated required memory for 169084 words and 128 dimensions: 257684016 bytes
# 2018-05-10 22:41:05,161 : INFO : resetting layer weights
# 2018-05-10 22:41:07,582 : INFO : training model with 20 workers on 169084 vocabulary and 128 features, using sg=1 hs=0 sample=0.001 negative=8 window=8
# 2018-05-10 22:41:08,750 : INFO : PROGRESS: at 0.02% examples, 14099 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:09,998 : INFO : PROGRESS: at 0.19% examples, 74655 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:11,162 : INFO : PROGRESS: at 0.37% examples, 95998 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:12,174 : INFO : PROGRESS: at 0.51% examples, 103240 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:13,242 : INFO : PROGRESS: at 0.61% examples, 99537 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:14,302 : INFO : PROGRESS: at 0.76% examples, 104463 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:15,333 : INFO : PROGRESS: at 0.80% examples, 103860 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:16,358 : INFO : PROGRESS: at 0.84% examples, 104138 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:17,376 : INFO : PROGRESS: at 0.89% examples, 103531 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:18,457 : INFO : PROGRESS: at 0.92% examples, 101727 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:19,645 : INFO : PROGRESS: at 0.98% examples, 102585 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:20,655 : INFO : PROGRESS: at 1.03% examples, 103494 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:21,847 : INFO : PROGRESS: at 1.07% examples, 102407 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:22,949 : INFO : PROGRESS: at 1.10% examples, 99054 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:24,017 : INFO : PROGRESS: at 1.15% examples, 100606 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:25,141 : INFO : PROGRESS: at 1.18% examples, 98611 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:26,151 : INFO : PROGRESS: at 1.23% examples, 99457 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:27,315 : INFO : PROGRESS: at 1.26% examples, 97079 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:28,373 : INFO : PROGRESS: at 1.30% examples, 96174 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:29,374 : INFO : PROGRESS: at 1.34% examples, 96292 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:30,480 : INFO : PROGRESS: at 1.38% examples, 95351 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:31,483 : INFO : PROGRESS: at 1.42% examples, 95549 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:32,614 : INFO : PROGRESS: at 1.45% examples, 94930 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:33,871 : INFO : PROGRESS: at 1.51% examples, 95106 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:34,885 : INFO : PROGRESS: at 1.55% examples, 95247 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:35,938 : INFO : PROGRESS: at 1.59% examples, 95506 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:36,981 : INFO : PROGRESS: at 1.63% examples, 95511 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:38,072 : INFO : PROGRESS: at 1.67% examples, 95116 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:39,099 : INFO : PROGRESS: at 1.71% examples, 95390 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:40,120 : INFO : PROGRESS: at 1.75% examples, 95252 words/s, in_qsize 40, out_qsize 1
# 2018-05-10 22:41:41,205 : INFO : PROGRESS: at 1.79% examples, 94931 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:42,215 : INFO : PROGRESS: at 1.83% examples, 94826 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:43,367 : INFO : PROGRESS: at 1.88% examples, 94790 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:44,391 : INFO : PROGRESS: at 1.93% examples, 95693 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:45,403 : INFO : PROGRESS: at 1.96% examples, 95568 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:46,469 : INFO : PROGRESS: at 2.01% examples, 95522 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:47,500 : INFO : PROGRESS: at 2.05% examples, 95553 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:48,504 : INFO : PROGRESS: at 2.09% examples, 95831 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:49,613 : INFO : PROGRESS: at 2.14% examples, 95681 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:50,642 : INFO : PROGRESS: at 2.18% examples, 95901 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:51,804 : INFO : PROGRESS: at 2.23% examples, 95813 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:52,884 : INFO : PROGRESS: at 2.27% examples, 95907 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:54,207 : INFO : PROGRESS: at 2.32% examples, 95506 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:55,311 : INFO : PROGRESS: at 2.36% examples, 95368 words/s, in_qsize 39, out_qsize 0
# 2018-05-10 22:41:56,318 : INFO : PROGRESS: at 2.42% examples, 95917 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:57,331 : INFO : PROGRESS: at 2.45% examples, 95821 words/s, in_qsize 40, out_qsize 0
# 2018-05-10 22:41:58,510 : INFO : PROGRESS: at 2.49% examples, 95395 words/s, in_qsize 40, out_qsize 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-558bd144a688> in <module>()
#      16                                   window=8,
#      17                                   negative=8,
# ---> 18                                   sg=1
#      19                                  )
#      20
#
# C:\Users\Johnson\Anaconda3\lib\site-packages\gensim\models\word2vec.py in __init__(self, sentences, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words, compute_loss)
#     552             self.train(
#     553                 sentences, total_examples=self.corpus_count, epochs=self.iter,
# --> 554                 start_alpha=self.alpha, end_alpha=self.min_alpha
#     555             )
#     556         else:
#
# C:\Users\Johnson\Anaconda3\lib\site-packages\gensim\models\word2vec.py in train(self, sentences, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss)
#    1074
#    1075         while unfinished_worker_count > 0:
# -> 1076             report = progress_queue.get()  # blocks if workers too slow
#    1077             if report is None:  # a thread reporting that it finished
#    1078                 unfinished_worker_count -= 1
#
# C:\Users\Johnson\Anaconda3\lib\queue.py in get(self, block, timeout)
#     162             elif timeout is None:
#     163                 while not self._qsize():
# --> 164                     self.not_empty.wait()
#     165             elif timeout < 0:
#     166                 raise ValueError("'timeout' must be a non-negative number")
#
# C:\Users\Johnson\Anaconda3\lib\threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %%
'''
用最新版本的keras训练模型，使用GPU加速
其中Bidirectional函数目前要在github版本才有

'''
from keras.layers import Dense, LSTM, Lambda, TimeDistributed, Input, Masking, Bidirectional
from keras.models import Model
from keras.utils import np_utils
from keras.regularizers import l1 #通过L1正则项，使得输出更加稀疏

# %%
sequence = Input(shape=(maxlen,word_size))
mask = Masking(mask_value=0.)(sequence)
blstm = Bidirectional(LSTM(64, return_sequences=True), merge_mode='sum')(mask)
blstm = Bidirectional(LSTM(32, return_sequences=True), merge_mode='sum')(blstm)
output = TimeDistributed(Dense(5, activation='softmax', activity_regularizer=l1(0.01)))(blstm)
model = Model(input=sequence, output=output)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


'''
gen_matrix实现从分词后的list来输出训练样本
gen_target实现将输出序列转换为one-hot形式的目标
超过maxlen则截断，不足补0
'''
gen_matrix = lambda z: np.vstack((word2vec[z[:maxlen]], np.zeros((maxlen-len(z[:maxlen]), word_size))))
gen_target = lambda z: np_utils.to_categorical(np.array(z[:maxlen] + [0]*(maxlen-len(z[:maxlen]))), 5)


#从节省内存的角度，通过生成器的方式来训练
def data_generator(data, targets, batch_size): 
    idx = np.arange(len(data))
    np.random.shuffle(idx)
    batches = [idx[range(batch_size*i, min(len(data), batch_size*(i+1)))] for i in range(len(data)/batch_size+1)]
    while True:
        for i in batches:
            xx, yy = np.array(map(gen_matrix, data[i])), np.array(map(gen_target, targets[i]))
            yield (xx, yy)
            
            
batch_size = 1024
history = model.fit_generator(data_generator(d['words'], d['label'], batch_size), samples_per_epoch=len(d), nb_epoch=200)
model.save_weights('words_seq2seq_final_1.model')


#输出预测结果（原始数据，未整理）
def predict_data(data, batch_size):
    batches = [range(batch_size*i, min(len(data), batch_size*(i+1))) for i in range(len(data)/batch_size+1)]
    p = model.predict(np.array(map(gen_matrix, data[batches[0]])), verbose=1)
    for i in batches[1:]:
        print min(i), 'done.'
        p = np.vstack((p, model.predict(np.array(map(gen_matrix, data[i])), verbose=1)))
    return p

d['predict'] = list(predict_data(d['words'],batch_size))
dd['predict'] = list(predict_data(dd['words'],batch_size))

'''
动态规划部分：
1：zy是转移矩阵，用了对数概率，概率的数值是大概估计的，事实上，这个数值的精确意义不是很大。
2：viterbi是动态规划算法
'''
zy = {'00':0.15, 
      '01':0.15, 
      '02':0.7, 
      '10':1.0, 
      '23':0.5, 
      '24':0.5,
      '33':0.5,
      '34':0.5, 
      '40':1.0
     }

zy = {i:np.log(zy[i]) for i in zy.keys()}

def viterbi(nodes):
    paths = nodes[0]
    for l in range(1,len(nodes)):
        paths_ = paths.copy()
        paths = {}
        for i in nodes[l].keys():
            nows = {}
            for j in paths_.keys():
                if j[-1]+i in zy.keys():
                    nows[j+i]= paths_[j]+nodes[l][i]+zy[j[-1]+i]
            k = np.argmax(nows.values())
            paths[nows.keys()[k]] = nows.values()[k]
    return paths.keys()[np.argmax(paths.values())]

'''
整理输出结果，即生成提交数据所需要的格式
整个过程包括：动态规划，结果提取
'''

def predict(i):
    nodes = [dict(zip(['0','1','2','3','4'], k)) for k in np.log(dd['predict'][i][:len(dd['words'][i])])]
    r = viterbi(nodes)
    result = []
    words = dd['words'][i]
    
    for j in re.finditer('2.*?4|1', r):
        result.append((''.join(words[j.start():j.end()]), np.mean([nodes[k][r[k]] for k in range(j.start(),j.end())])))
    if result:
        result = pd.DataFrame(result)
        return [result[0][result[1].argmax()]]
    else:
        return result
    
dd['core_entiry'] = map(predict,tqdm(iter(dd.index),desc='第一次预测'))


'''
导出提交的json格式
'''
gen = lambda i:'[{"content": "'+dd.iloc[i]['content']+'", "core_entity": ["'+''.join(dd.iloc[i]['core_entity'])+'"]}]'
ssss = map(gen,tqdm(range(len(dd))))
result = '\n'.join(ssss)
import codecs
f = codecs.open('result.txt','w',encoding='utf-8')
f.write(result)
f.close()
import os
os.system('rm result1.zip')
os.system('zip result1.zip result1.txt')
print('正在进行第一次迁移学习。。。')

'''
开始迁移学习
'''
def label(k): #将输出结果转换为标签序列
    s = dd['words'][k]
    r = ['0']*len(s)
    for i in range(len(s)):
        for j in dd['core_entity'][k]:
            if s[i] in j:
                r[i] = '1'
                break
    s = ''.join(r)
    r = [0]*len(s)
    for i in re.finditer('1+', s):
        if i.end() - i.start() > 1:
            r[i.start()] = 2
            r[i.end()-1] = 4
            for j in range(i.start()+1, i.end()-1):
                r[j] = 3
        else:
            r[i.start()] = 1
    return r

dd['label'] = map(label, tqdm(iter(dd.index))) #输出tags

'''
将测试集和训练集一起放到模型中训练，
其中测试集的样本权重设置为1，训练集为10
'''
w = np.array([1]*len(dd) + [10]*len(d))
def data_generator(data, targets, batch_size):
    idx = np.arange(len(data))
    np.random.shuffle(idx)
    batches = [idx[range(batch_size*i, min(len(data), batch_size*(i+1)))] for i in range(len(data)/batch_size+1)]
    while True:
        for i in batches:
            xx, yy = np.array(map(gen_matrix, data[i])), np.array(map(gen_target, targets[i]))
            yield (xx, yy, w[i])

history = model.fit_generator(data_generator(
                                    dd[['words']].append(d[['words']], ignore_index=True)['words'],
                                    dd[['label']].append(d[['label']], ignore_index=True)['label'],
                                    batch_size),
                              samples_per_epoch=len(dd)+len(d),
                              nb_epoch=20)

model.save_weights('words_seq2seq_final_2.model')
d['predict'] = list(predict_data(d['words'], batch_size))
dd['predict'] = list(predict_data(dd['words'], batch_size))
dd['core_entity_2'] = map(predict, tqdm(iter(dd.index), desc=u'第一次迁移学习预测'))


'''
导出提交的JSON格式
'''
gen = lambda i:'[{"content": "'+dd.iloc[i]['content']+'", "core_entity": ["'+''.join(dd.iloc[i]['core_entity_2'])+'"]}]'
ssss = map(gen, tqdm(range(len(dd))))
result='\n'.join(ssss)
import codecs
f=codecs.open('result2.txt', 'w', encoding='utf-8')
f.write(result)
f.close()
import os
os.system('rm result2.zip')
os.system('zip result2.zip result2.txt')


print (u'正在进行第二次迁移学习......')

'''
开始迁移学习2。
'''

ddd = dd[dd['core_entity'] == dd['core_entity_2']].copy()

'''
将测试集和训练集一起放到模型中训练，
其中测试集的样本权重设置为1，训练集为5
'''
w = np.array([1]*len(ddd) + [5]*len(d))
def data_generator(data, targets, batch_size):
    idx = np.arange(len(data))
    np.random.shuffle(idx)
    batches = [idx[range(batch_size*i, min(len(data), batch_size*(i+1)))] for i in range(len(data)/batch_size+1)]
    while True:
        for i in batches:
            xx, yy = np.array(map(gen_matrix, data[i])), np.array(map(gen_target, targets[i]))
            yield (xx, yy, w[i])

history = model.fit_generator(data_generator(
                                    ddd[['words']].append(d[['words']], ignore_index=True)['words'],
                                    ddd[['label']].append(d[['label']], ignore_index=True)['label'],
                                    batch_size),
                              samples_per_epoch=len(ddd)+len(d),
                              nb_epoch=20)

model.save_weights('words_seq2seq_final_3.model')
d['predict'] = list(predict_data(d['words'], batch_size))
dd['predict'] = list(predict_data(dd['words'], batch_size))
dd['core_entity_3'] = map(predict, tqdm(iter(dd.index), desc=u'第二次迁移学习预测'))

'''
导出提交的JSON格式
'''
gen = lambda i:'[{"content": "'+dd.iloc[i]['content']+'", "core_entity": ["'+''.join(dd.iloc[i]['core_entity_3'])+'"]}]'
ssss = map(gen, tqdm(range(len(dd))))
result='\n'.join(ssss)
import codecs
f=codecs.open('result3.txt', 'w', encoding='utf-8')
f.write(result)
f.close()
import os
os.system('rm result3.zip')
os.system('zip result3.zip result3.txt')



print (u'正在进行第三次迁移学习......')


'''
开始迁移学习3。
'''

ddd = dd[dd['core_entity'] == dd['core_entity_2']].copy()
ddd = ddd[ddd['core_entity_3'] == ddd['core_entity_2']].copy()

'''
将测试集和训练集一起放到模型中训练，
其中测试集的样本权重设置为1，训练集为1
'''
w = np.array([1]*len(ddd) + [1]*len(d))
def data_generator(data, targets, batch_size):
    idx = np.arange(len(data))
    np.random.shuffle(idx)
    batches = [idx[range(batch_size*i, min(len(data), batch_size*(i+1)))] for i in range(len(data)/batch_size+1)]
    while True:
        for i in batches:
            xx, yy = np.array(map(gen_matrix, data[i])), np.array(map(gen_target, targets[i]))
            yield (xx, yy, w[i])

history = model.fit_generator(data_generator(
                                    ddd[['words']].append(d[['words']], ignore_index=True)['words'],
                                    ddd[['label']].append(d[['label']], ignore_index=True)['label'],
                                    batch_size),
                              samples_per_epoch=len(ddd)+len(d),
                              nb_epoch=20)

model.save_weights('words_seq2seq_final_4.model')
d['predict'] = list(predict_data(d['words'], batch_size))
dd['predict'] = list(predict_data(dd['words'], batch_size))
dd['core_entity_4'] = map(predict, tqdm(iter(dd.index), desc=u'第三次迁移学习预测'))

'''
导出提交的JSON格式
'''
gen = lambda i:'[{"content": "'+dd.iloc[i]['content']+'", "core_entity": ["'+''.join(dd.iloc[i]['core_entity_4'])+'"]}]'
ssss = map(gen, tqdm(range(len(dd))))
result='\n'.join(ssss)
import codecs
f=codecs.open('result4.txt', 'w', encoding='utf-8')
f.write(result)
f.close()
import os
os.system('rm result4.zip')
os.system('zip result4.zip result4.txt')



print (u'正在进行第四次迁移学习......')


'''
开始迁移学习4。
'''

ddd = dd[dd['core_entity'] == dd['core_entity_2']].copy()
ddd = ddd[ddd['core_entity_3'] == ddd['core_entity_2']].copy()
ddd = ddd[ddd['core_entity_4'] == ddd['core_entity_2']].copy()

'''
将测试集和训练集一起放到模型中训练，
其中测试集的样本权重设置为1，训练集为1
'''
w = np.array([1]*len(ddd) + [1]*len(d))
def data_generator(data, targets, batch_size):
    idx = np.arange(len(data))
    np.random.shuffle(idx)
    batches = [idx[range(batch_size*i, min(len(data), batch_size*(i+1)))] for i in range(len(data)/batch_size+1)]
    while True:
        for i in batches:
            xx, yy = np.array(map(gen_matrix, data[i])), np.array(map(gen_target, targets[i]))
            yield (xx, yy, w[i])

history = model.fit_generator(data_generator(
                                    ddd[['words']].append(d[['words']], ignore_index=True)['words'],
                                    ddd[['label']].append(d[['label']], ignore_index=True)['label'],
                                    batch_size),
                              samples_per_epoch=len(ddd)+len(d),
                              nb_epoch=20)

model.save_weights('words_seq2seq_final_5.model')
d['predict'] = list(predict_data(d['words'], batch_size))
dd['predict'] = list(predict_data(dd['words'], batch_size))
dd['core_entity_5'] = map(predict, tqdm(iter(dd.index), desc=u'第四次迁移学习预测'))

'''
导出提交的JSON格式
'''
gen = lambda i:'[{"content": "'+dd.iloc[i]['content']+'", "core_entity": ["'+''.join(dd.iloc[i]['core_entity_5'])+'"]}]'
ssss = map(gen, tqdm(range(len(dd))))
result='\n'.join(ssss)
import codecs
f=codecs.open('result5.txt', 'w', encoding='utf-8')
f.write(result)
f.close()
import os
os.system('rm result5.zip')
os.system('zip result5.zip result5.txt')
